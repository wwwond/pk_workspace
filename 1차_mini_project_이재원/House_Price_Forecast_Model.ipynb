# %% [markdown]
# ### 주택 가격 예측 모델 (머신러닝)

# %% [markdown]
# #### 라이브러리 선언

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", family = "Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn import set_config
set_config(display="text")
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler, RobustScaler
from xgboost import XGBRegressor
from scipy.stats import spearmanr
import time
import pickle
import os

### 주택가격 예측모델 흐름 ppt 개요 만들기~

# %% [markdown]
# #### 전처리 이후 데이터 읽어들이기

# %%
df= pd.read_csv("./data/data_preprocessing.csv")
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3           65     8450       1      0         3
# 1             20         3           80     9600       1      0         3
# 2             60         3           68    11250       1      0         0
# 3             70         3           60     9550       1      0         0
# 4             60         3           84    14260       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3           62     7917       1      0         3
# 1456          20         3           85    13175       1      0         3
# 1457          70         3           66     9042       1      0         3
# 1458          20         3           68     9717       1      0         3
# 1459          20         3           75     9937       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0               3          0          4  ...         0       0      0
# 1               3          0          2  ...         0       0      0
# 2               3          0          4  ...         0       0      0
# 3               3          0          0  ...         0       0      0
# 4               3          0          2  ...         0       0      0
# ...           ...        ...        ...  ...       ...     ...    ...
# 1455            3          0          4  ...         0       0      0
# 1456            3          0          4  ...         0       0      3
# 1457            3          0          4  ...         0       0      4
# 1458            3          0          4  ...         0       0      0
# 1459            3          0          4  ...         0       0      0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0               0        0       2    2008         8              4     208500
# 1               0        0       5    2007         8              4     181500
# 2               0        0       9    2008         8              4     223500
# 3               0        0       2    2006         8              0     140000
# 4               0        0      12    2008         8              4     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455            0        0       8    2007         8              4     175000
# 1456            0        0       2    2010         8              4     210000
# 1457            1     2500       5    2010         8              4     266500
# 1458            0        0       4    2010         8              4     142125
# 1459            0        0       6    2008         8              4     147500
#
# [1460 rows x 80 columns]

# %% [markdown]
# ### 데이터분리

# %%
### 종속변수, 독립변수 분리
# 독립변수 금액을 제외한 모든 컬럼
# 종속변수 금액

x = df.iloc[:,:-1]
y = df["SalePrice"]
print(x.shape, y.shape)
# Out:
# (1460, 79) (1460,)

# %%
### 훈련 : 테스트 // 6:2:2
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1168, 79) (1168,)
# (146, 79) (146,)
# (146, 79) (146,)

# %% [markdown]
# ### 모델정의

# %%
lr  = LinearRegression()
rd  = Ridge()
ls = Lasso()
rf  = RandomForestRegressor()
ext = ExtraTreesRegressor()
gb  = GradientBoostingRegressor()
hgb = HistGradientBoostingRegressor()
xgb = XGBRegressor()

models = [lr, rd, ls, rf, ext, gb, hgb, xgb]
models
# Out:
# [LinearRegression(),
#  Ridge(),
#  Lasso(),
#  RandomForestRegressor(),
#  ExtraTreesRegressor(),
#  GradientBoostingRegressor(),
#  HistGradientBoostingRegressor(),
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)]

# %% [markdown]
# ### 기본모델 훈련하기

# %%
for model in models:
    model_name = model.__class__.__name__

    model.fit(x_train, y_train)

    # 모델 점수
    train_score = model.score(x_train, y_train)
    val_score = model.score(x_val, y_val)
    test_score = model.score(x_test, y_test)

    # 예측 값 계산
    train_pred = model.predict(x_train)
    val_pred = model.predict(x_val)
    test_pred = model.predict(x_test)

    # 평가 지표
    train_mae = mean_absolute_error(y_train, train_pred)
    val_mae = mean_absolute_error(y_val, val_pred)
    test_mae = mean_absolute_error(y_test, test_pred)

    train_mse = mean_squared_error(y_train, train_pred)
    val_mse = mean_squared_error(y_val, val_pred)
    test_mse = mean_squared_error(y_test, test_pred)

    train_r2 = r2_score(y_train, train_pred)
    val_r2 = r2_score(y_val, val_pred)
    test_r2 = r2_score(y_test, test_pred)

    # 결과 출력
    print(f"---- {model_name} ----")
    print(f"과적합 여부: {train_score - val_score:.4f}")
    print(f"훈련 MAE: {train_mae:.4f}, 검증 MAE: {test_mae:.4f}, 테스트 MAE: {test_mae:.4f}")
    print(f"훈련 MSE: {train_mse:.4f}, 검증 MSE: {val_mse:.4f}, 테스트 MSE: {test_mse:.4f}")
    print(f"훈련 R²: {train_r2:.4f}, 검증 R²: {val_r2:.4f},  테스트 R²: {test_r2:.4f}")
    print("=" * 50)
# Out:
# ---- LinearRegression ----
# 과적합 여부: -0.0405
# 훈련 MAE: 19003.6647, 검증 MAE: 22959.1351, 테스트 MAE: 22959.1351
# 훈련 MSE: 931633756.3199, 검증 MSE: 677925892.5599, 테스트 MSE: 1622173379.8210
# 훈련 R²: 0.8438, 검증 R²: 0.8843,  테스트 R²: 0.8276
# ==================================================
# ---- Ridge ----
# 과적합 여부: -0.0411
# 훈련 MAE: 18994.6934, 검증 MAE: 22902.5879, 테스트 MAE: 22902.5879
# 훈련 MSE: 932502156.5588, 검증 MSE: 674871315.3328, 테스트 MSE: 1620099165.1757
# 훈련 R²: 0.8437, 검증 R²: 0.8848,  테스트 R²: 0.8278
# ==================================================
# ---- Lasso ----
# 과적합 여부: -0.0405
# 훈련 MAE: 19001.1175, 검증 MAE: 22954.2477, 테스트 MAE: 22954.2477
# 훈련 MSE: 931635589.2050, 검증 MSE: 677714545.6771, 테스트 MSE: 1622008706.9513
# 훈련 R²: 0.8438, 검증 R²: 0.8843,  테스트 R²: 0.8276
# ==================================================
# ---- RandomForestRegressor ----
# 과적합 여부: 0.0749
# 훈련 MAE: 6477.0634, 검증 MAE: 19157.2718, 테스트 MAE: 19157.2718
# 훈련 MSE: 119509699.2913, 검증 MSE: 556486832.8380, 테스트 MSE: 1053353930.6496
# 훈련 R²: 0.9800, 검증 R²: 0.9050,  테스트 R²: 0.8880
# ==================================================
# ---- ExtraTreesRegressor ----
# 과적합 여부: 0.0821
# 훈련 MAE: 0.0000, 검증 MAE: 18984.7740, 테스트 MAE: 18984.7740
# 훈련 MSE: 0.0000, 검증 MSE: 480828703.1702, 테스트 MSE: 1184077063.3966
# 훈련 R²: 1.0000, 검증 R²: 0.9179,  테스트 R²: 0.8742
# ==================================================
# ---- GradientBoostingRegressor ----
# 과적합 여부: 0.0607
# 훈련 MAE: 9847.2682, 검증 MAE: 19130.9140, 테스트 MAE: 19130.9140
# 훈련 MSE: 179748895.9204, 검증 MSE: 532275369.1167, 테스트 MSE: 1108290869.5452
# 훈련 R²: 0.9699, 검증 R²: 0.9091,  테스트 R²: 0.8822
# ==================================================
# ---- HistGradientBoostingRegressor ----
# 과적합 여부: 0.0670
# 훈련 MAE: 5261.8569, 검증 MAE: 18062.8083, 테스트 MAE: 18062.8083
# 훈련 MSE: 127043021.0375, 검증 MSE: 517563276.5771, 테스트 MSE: 1119222104.2253
# 훈련 R²: 0.9787, 검증 R²: 0.9117,  테스트 R²: 0.8810
# ==================================================
# ---- XGBRegressor ----
# 과적합 여부: 0.1009
# 훈련 MAE: 714.4966, 검증 MAE: 17634.9145, 테스트 MAE: 17634.9145
# 훈련 MSE: 1039348.1462, 검증 MSE: 591921872.9063, 테스트 MSE: 694349871.7953
# 훈련 R²: 0.9998, 검증 R²: 0.8990,  테스트 R²: 0.9262
# ==================================================

# %%
"""
<기본 모델 해석>
- 주택가격을 예측하기 위하여 8개의 모델로 훈련 평가를 수행한 결과는 위와 같다.
 -- 훈련 결정계수가 1.0으로 나타난 모델은 1개 (ExtraTreesRegressor), 과대 적합이 발생한 모델은 1개 (XGBRegressor)로 보이며
 -- 과소적합이 발생한 모델은 3개(LinearRegression), (Ridge), (Lasso)이다 이를 제외한 모델은 일반화가 잘된 것으로 판단된다.
 -- 각 모델들의 훈련 결정계수의 범위는 0.84 ~ 1.0 사이로 매우 훌륭한 모델이며 그 중 아래 모델이 최고의 모델로 선정하였다.

---- GradientBoostingRegressor ----
과적합 여부: 0.0607
훈련 MAE: 9847.2682, 검증 MAE: 19130.9140, 테스트 MAE: 19130.9140
훈련 MSE: 179748895.9204, 검증 MSE: 532275369.1167, 테스트 MSE: 1108290869.5452
훈련 R²: 0.9699, 검증 R²: 0.9091,  테스트 R²: 0.8822

훈련 R²이 0.9699 매우 훌륭한 모델이 도출되었으나 검증R²값이 상대적으로 낮아
검증R²를 높일 수 있는 방법을 모색해야 봐야할 것으로 판단됨
검증R²를 높이기 위해 스케일링, 하이퍼파라메터 수정을 선행해야할 것으로 판단됨
또한 과소적합을 비롯한 일반화가 잘 되지 않은 모델들이 많아 위와 같은 수정이 필요할 것으로 판단됨 
"""
# Out:
# '\n<기본 모델 해석>\n- 주택가격을 예측하기 위하여 8개의 모델로 훈련 평가를 수행한 결과는 위와 같다.\n -- 과대적합이 발생한 모델은 2개(HistGradientBoostingRegressor , ExtraTreesRegressor)이고, 그 외 6개의 모델은 일반화가 잘된 것으로 나타남\n -- 각 모델들의 훈련 결정계수의 범위는 0.84 ~ 1.0 사이로 매우 훌륭한 모델이며 그 중 아래 모델이 최고의 모델로 선정하였다.\n\n---- XGBRegressor ----\n과적합 여부: 0.0821\n훈련 MAE: 656.0961, 검증 MAE: 18082.0161, 테스트 MAE: 18082.0161\n훈련 MSE: 899203.6555, 검증 MSE: 551382406.9169, 테스트 MSE: 773861925.7549\n훈련 R²: 0.9998, 검증 R²: 0.9059,  테스트 R²: 0.9178\n\n훈련 R²이 0.9998로 매우 훌륭한 모델이 도출되었으나 검증R²값이 상대적으로 낮아\n검증R²를 높일 수 있는 방법을 모색해야 봐야할 것으로 판단됨\n검증R²를 높이기 위해 스케일링, 하이퍼파라메터 수정을 선행해야할 것으로 판단됨\n'

# %% [markdown]
# ### 전처리 이후 하이퍼파라메터 수정, 스케일링 모델 돌려보기

# %%
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)
rs_df = pd.DataFrame()
for degree in range(1,2):
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    poly.fit(x_train)

    train_poly = poly.transform(x_train)
    val_poly = poly.transform(x_val)
    test_poly = poly.transform(x_test)
    scalers = {"StandardScaler": StandardScaler(),
        "MinMaxScaler": MinMaxScaler(),
        "RobustScaler": RobustScaler(),
        "No Scaling": None}

for scaler_name, scaler in scalers.items():
    if scaler:
        train_scaled = scaler.fit_transform(train_poly)
        val_scaled = scaler.transform(val_poly)
        test_scaled = scaler.transform(test_poly)
    else:
        train_scaled = x_train
        val_scaled = x_val
        test_scaled = x_test

    for model in models:
        model_nm = model.__class__.__name__
        start_time = time.time()
        for idx in range(0,2):
            if idx == 0 :
                param_grid = {
                    "LinearRegression": {},
                    "Ridge": {"alpha": [0.1, 1, 10, 100], "max_iter": [5000, 10000]},
                    "Lasso": {"alpha": [0.1, 1, 10, 100], "max_iter": [5000, 10000]},
                    "RandomForestRegressor": {"n_estimators": [50, 100, 200], "max_depth": [5, 10, 15], "min_samples_split": [2, 5]},
                    "ExtraTreesRegressor": {"n_estimators": [50, 100, 200], "max_depth": [5, 10, 15], "min_samples_split": [2, 5]},
                    "GradientBoostingRegressor": {"n_estimators": [50, 100, 200],"learning_rate": [0.01, 0.1, 0.2], "max_depth": [3, 5, 7]},
                    "HistGradientBoostingRegressor": {"max_iter": [50, 100, 200], "learning_rate": [0.01, 0.1], "max_depth": [3, 5]},
                    "XGBRegressor": {"n_estimators": [50, 100, 200],"max_depth": [3, 5, 7], "learning_rate": [0.01, 0.1], "min_child_weight": [1, 2]},
                }.get(model_nm, {})  # 딕셔너리 키를 찾아 값 반환 (하이퍼파라메터값)

            else :
                param_grid = {}
            default_model = model.__class__()  # 기본 모델 생성
            default_model.fit(train_scaled, y_train)
            default_train_pred = default_model.predict(train_scaled)
            default_val_pred = default_model.predict(val_scaled)

            # 기본 모델 평가 점수 계산
            default_train_r2 = round(r2_score(y_train, default_train_pred), 4)
            default_val_r2 = round(r2_score(y_val, default_val_pred), 4)
            default_train_val_diff = round(default_train_r2 - default_val_r2, 4)


            grid_search = GridSearchCV(
                estimator=model,
                param_grid=param_grid,
                scoring="r2",
                refit=True, # 가장 좋은 하이퍼파라메터를 저장
                cv=5,
                n_jobs=-1)

            grid_search.fit(train_scaled, y_train)
            best_model = grid_search.best_estimator_
            best_params = grid_search.best_params_
            
            ### 모델 저장    
            model_filename = f"{save_dir}/{model_nm}_{scaler_name}_best.pkl"
            with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)

            print(f"🔹 최적 모델 저장 완료: {model_filename}")
            
            
            train_pred = best_model.predict(train_scaled)
            val_pred = best_model.predict(val_scaled)
            test_pred = best_model.predict(test_scaled)

            train_mae = round(mean_absolute_error(y_train, train_pred), 4)
            train_mse = round(mean_squared_error(y_train, train_pred), 4)
            train_r2 = round(r2_score(y_train, train_pred), 4)
            
            val_mae = round(mean_absolute_error(y_val, val_pred), 4)
            val_mse = round(mean_squared_error(y_val, val_pred), 4)
            val_r2 = round(r2_score(y_val, val_pred), 4)
            
            test_mae = round(mean_absolute_error(y_test, test_pred), 4)
            test_mse = round(mean_squared_error(y_test, test_pred), 4)
            test_r2 = round(r2_score(y_test, test_pred), 4)
            train_val_diff = round(train_r2 - val_r2, 4)

            msg = (f"모델명: {model_nm}, 사용된 스케일러: {scaler_name}"
                f" 최적 하이퍼파라미터: {best_params}\n"
                f"훈련MAE: {train_mae:.4f}, 훈련MSE: {train_mse:.4f}, 훈련R2: {train_r2:.4f}\n"
                f"검증MAE: {val_mae:.4f}, 검증MSE: {val_mse:.4f}, 검증R2: {val_r2:.4f}\n"
                f"테스트MAE: {test_mae:.4f}, 테스트MSE: {test_mse:.4f}, 테스트R2: {test_r2:.4f}\n"
                f"과적합여부(R2 차이): {train_val_diff:.4f}")
            print(msg, "\n")
            print("===================================")
            if (train_r2 != 1) & (train_val_diff < 0.1):
                df_data = pd.DataFrame([[model_nm, degree, scaler_name, best_params, train_mse, val_mse, test_mse,
                                        train_r2, val_r2, test_r2, train_val_diff]],
                                        columns=["모델명","특성공학","스케일링", "하이퍼파라메터_튜닝", "훈련MSE", "검증MSE","테스트MSE",
                                                "훈련R2", "검증R2","테스트R2", "과적합여부"])
                rs_df = pd.concat([rs_df, df_data], ignore_index=True)
                end_time = time.time()
                elapsed_time = end_time - start_time

        print(f"모델 학습 소요 시간: {elapsed_time:.2f}초")
        print(f"start_time:{start_time}\n")
# 특성공학 : 1  하이퍼 파라메터_튜닝은 : 베스트로 기재될 예정입니다.
# Out:
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_StandardScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.7184, 훈련MSE: 931610011.3391, 훈련R2: 0.8438
# 검증MAE: 19877.6009, 검증MSE: 677795814.4206, 검증R2: 0.8843
# 테스트MAE: 22962.5340, 테스트MSE: 1620500550.9756, 테스트R2: 0.8278
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_StandardScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.7184, 훈련MSE: 931610011.3391, 훈련R2: 0.8438
# 검증MAE: 19877.6009, 검증MSE: 677795814.4206, 검증R2: 0.8843
# 테스트MAE: 22962.5340, 테스트MSE: 1620500550.9756, 테스트R2: 0.8278
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 4.28초
# start_time:1742782532.9162042
#
# 🔹 최적 모델 저장 완료: saved_models/Ridge_StandardScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18728.5328, 훈련MSE: 947173774.5389, 훈련R2: 0.8412
# 검증MAE: 19184.8801, 검증MSE: 648496478.5713, 검증R2: 0.8893
# 테스트MAE: 22391.4858, 테스트MSE: 1627312804.5323, 테스트R2: 0.8270
# 과적합여부(R2 차이): -0.0481
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Ridge_StandardScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 18994.7731, 훈련MSE: 931639914.6138, 훈련R2: 0.8438
# 검증MAE: 19871.3622, 검증MSE: 677266227.8518, 검증R2: 0.8844
# 테스트MAE: 22942.9905, 테스트MSE: 1621435617.4078, 테스트R2: 0.8277
# 과적합여부(R2 차이): -0.0406
#
# ===================================
# 모델 학습 소요 시간: 0.96초
# start_time:1742782537.1936915
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.801e+09, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# 🔹 최적 모델 저장 완료: saved_models/Lasso_StandardScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18865.8776, 훈련MSE: 933352765.8685, 훈련R2: 0.8435
# 검증MAE: 19680.7226, 검증MSE: 662006870.2364, 검증R2: 0.8870
# 테스트MAE: 22738.5751, 테스트MSE: 1620490484.9558, 테스트R2: 0.8278
# 과적합여부(R2 차이): -0.0435
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Lasso_StandardScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19001.3449, 훈련MSE: 931633982.2601, 훈련R2: 0.8438
# 검증MAE: 19882.1598, 검증MSE: 677742838.4306, 검증R2: 0.8843
# 테스트MAE: 22956.0979, 테스트MSE: 1622092569.3093, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 0.59초
# start_time:1742782538.1552975
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.801e+09, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.801e+09, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_StandardScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 100}
# 훈련MAE: 7280.5247, 훈련MSE: 168772289.1390, 훈련R2: 0.9717
# 검증MAE: 15316.0318, 검증MSE: 532395439.1958, 검증R2: 0.9091
# 테스트MAE: 19891.8600, 테스트MSE: 1134269666.1979, 테스트R2: 0.8794
# 과적합여부(R2 차이): 0.0626
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_StandardScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 6684.6952, 훈련MSE: 136779663.3131, 훈련R2: 0.9771
# 검증MAE: 15428.5284, 검증MSE: 551071549.7505, 검증R2: 0.9059
# 테스트MAE: 19770.7879, 테스트MSE: 1141766859.0256, 테스트R2: 0.8787
# 과적합여부(R2 차이): 0.0712
#
# ===================================
# 모델 학습 소요 시간: 13.96초
# start_time:1742782538.7494013
#
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_StandardScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 훈련MAE: 753.3275, 훈련MSE: 1544182.3752, 훈련R2: 0.9997
# 검증MAE: 15009.4651, 검증MSE: 500049363.6916, 검증R2: 0.9146
# 테스트MAE: 19696.2398, 테스트MSE: 1217404849.3784, 테스트R2: 0.8706
# 과적합여부(R2 차이): 0.0851
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_StandardScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 0.0000, 훈련MSE: 0.0000, 훈련R2: 1.0000
# 검증MAE: 14536.2466, 검증MSE: 455145007.9923, 검증R2: 0.9223
# 테스트MAE: 19374.3053, 테스트MSE: 1166165606.3613, 테스트R2: 0.8761
# 과적합여부(R2 차이): 0.0777
#
# ===================================
# 모델 학습 소요 시간: 6.11초
# start_time:1742782552.7069361
#
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_StandardScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# 훈련MAE: 7648.5368, 훈련MSE: 102921559.9290, 훈련R2: 0.9827
# 검증MAE: 14813.2361, 검증MSE: 507052944.4027, 검증R2: 0.9135
# 테스트MAE: 18065.0272, 테스트MSE: 1053585478.6711, 테스트R2: 0.8880
# 과적합여부(R2 차이): 0.0692
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_StandardScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 9847.2682, 훈련MSE: 179748895.9204, 훈련R2: 0.9699
# 검증MAE: 15462.4352, 검증MSE: 531734785.0285, 검증R2: 0.9092
# 테스트MAE: 19058.2367, 테스트MSE: 1097882658.9608, 테스트R2: 0.8833
# 과적합여부(R2 차이): 0.0607
#
# ===================================
# 모델 학습 소요 시간: 12.04초
# start_time:1742782561.4698343
#
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_StandardScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'max_iter': 200}
# 훈련MAE: 9342.6052, 훈련MSE: 195615785.1160, 훈련R2: 0.9672
# 검증MAE: 14563.4503, 검증MSE: 499728713.3214, 검증R2: 0.9147
# 테스트MAE: 18443.0473, 테스트MSE: 1190171475.9860, 테스트R2: 0.8735
# 과적합여부(R2 차이): 0.0525
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_StandardScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 5261.8569, 훈련MSE: 127043021.0375, 훈련R2: 0.9787
# 검증MAE: 14871.8871, 검증MSE: 517003499.3932, 검증R2: 0.9118
# 테스트MAE: 18062.8083, 테스트MSE: 1119222104.2253, 테스트R2: 0.8810
# 과적합여부(R2 차이): 0.0669
#
# ===================================
# 모델 학습 소요 시간: 3.12초
# start_time:1742782573.5077038
#
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_StandardScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200}
# 훈련MAE: 8192.8810, 훈련MSE: 127122312.3656, 훈련R2: 0.9787
# 검증MAE: 15409.4190, 검증MSE: 495007880.4793, 검증R2: 0.9155
# 테스트MAE: 18168.0430, 테스트MSE: 919637429.7294, 테스트R2: 0.9023
# 과적합여부(R2 차이): 0.0632
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_StandardScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: StandardScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 714.4966, 훈련MSE: 1039348.1462, 훈련R2: 0.9998
# 검증MAE: 15912.8316, 검증MSE: 591921872.9063, 검증R2: 0.8990
# 테스트MAE: 17634.9145, 테스트MSE: 694349871.7953, 테스트R2: 0.9262
# 과적합여부(R2 차이): 0.1008
#
# ===================================
# 모델 학습 소요 시간: 6.82초
# start_time:1742782576.630488
#
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_MinMaxScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19023.1506, 훈련MSE: 933037477.5164, 훈련R2: 0.8436
# 검증MAE: 20002.2563, 검증MSE: 676578944.7443, 검증R2: 0.8845
# 테스트MAE: 23102.8681, 테스트MSE: 1625141860.5381, 테스트R2: 0.8273
# 과적합여부(R2 차이): -0.0409
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_MinMaxScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19023.1506, 훈련MSE: 933037477.5164, 훈련R2: 0.8436
# 검증MAE: 20002.2563, 검증MSE: 676578944.7443, 검증R2: 0.8845
# 테스트MAE: 23102.8681, 테스트MSE: 1625141860.5381, 테스트R2: 0.8273
# 과적합여부(R2 차이): -0.0409
#
# ===================================
# 모델 학습 소요 시간: 0.27초
# start_time:1742782583.9063413
#
# 🔹 최적 모델 저장 완료: saved_models/Ridge_MinMaxScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'alpha': 10, 'max_iter': 5000}
# 훈련MAE: 19843.4617, 훈련MSE: 1038073399.8809, 훈련R2: 0.8260
# 검증MAE: 19535.5372, 검증MSE: 670487151.3327, 검증R2: 0.8856
# 테스트MAE: 23624.7778, 테스트MSE: 1850010984.2127, 테스트R2: 0.8034
# 과적합여부(R2 차이): -0.0596
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Ridge_MinMaxScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 18919.5309, 훈련MSE: 943646447.9950, 훈련R2: 0.8418
# 검증MAE: 19688.7624, 검증MSE: 653549909.6611, 검증R2: 0.8884
# 테스트MAE: 22566.2430, 테스트MSE: 1616080013.5607, 테스트R2: 0.8282
# 과적합여부(R2 차이): -0.0466
#
# ===================================
# 모델 학습 소요 시간: 0.10초
# start_time:1742782584.1763165
#
# 🔹 최적 모델 저장 완료: saved_models/Lasso_MinMaxScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 19181.3942, 훈련MSE: 986741746.9641, 훈련R2: 0.8346
# 검증MAE: 19515.0721, 검증MSE: 631089884.4075, 검증R2: 0.8923
# 테스트MAE: 23010.8727, 테스트MSE: 1700593463.3644, 테스트R2: 0.8193
# 과적합여부(R2 차이): -0.0577
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Lasso_MinMaxScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 18983.3797, 훈련MSE: 931658748.5941, 훈련R2: 0.8438
# 검증MAE: 19872.6091, 검증MSE: 676156777.8589, 검증R2: 0.8846
# 테스트MAE: 22929.7124, 테스트MSE: 1620535251.5704, 테스트R2: 0.8278
# 과적합여부(R2 차이): -0.0408
#
# ===================================
# 모델 학습 소요 시간: 0.23초
# start_time:1742782584.2755234
#
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_MinMaxScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 50}
# 훈련MAE: 7364.6059, 훈련MSE: 179763331.1467, 훈련R2: 0.9699
# 검증MAE: 15223.4690, 검증MSE: 512544074.4913, 검증R2: 0.9125
# 테스트MAE: 20230.8347, 테스트MSE: 1245013087.8772, 테스트R2: 0.8677
# 과적합여부(R2 차이): 0.0574
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_MinMaxScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 6470.8132, 훈련MSE: 121094801.9885, 훈련R2: 0.9797
# 검증MAE: 15252.9327, 검증MSE: 548973542.3107, 검증R2: 0.9063
# 테스트MAE: 19454.8340, 테스트MSE: 1061871104.9226, 테스트R2: 0.8871
# 과적합여부(R2 차이): 0.0734
#
# ===================================
# 모델 학습 소요 시간: 13.66초
# start_time:1742782584.5072207
#
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_MinMaxScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 50}
# 훈련MAE: 2619.1561, 훈련MSE: 17334200.6299, 훈련R2: 0.9971
# 검증MAE: 14238.9250, 검증MSE: 430254589.7713, 검증R2: 0.9266
# 테스트MAE: 19609.5307, 테스트MSE: 1281538172.0322, 테스트R2: 0.8638
# 과적합여부(R2 차이): 0.0705
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_MinMaxScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 0.0000, 훈련MSE: 0.0000, 훈련R2: 1.0000
# 검증MAE: 14915.9925, 검증MSE: 469270650.8205, 검증R2: 0.9199
# 테스트MAE: 19990.5334, 테스트MSE: 1319827385.0488, 테스트R2: 0.8597
# 과적합여부(R2 차이): 0.0801
#
# ===================================
# 모델 학습 소요 시간: 5.70초
# start_time:1742782598.1705139
#
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_MinMaxScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 훈련MAE: 2907.4231, 훈련MSE: 14194211.0192, 훈련R2: 0.9976
# 검증MAE: 14450.7602, 검증MSE: 465569997.1167, 검증R2: 0.9205
# 테스트MAE: 17546.4826, 테스트MSE: 793748035.9581, 테스트R2: 0.9156
# 과적합여부(R2 차이): 0.0771
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_MinMaxScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 9847.2682, 훈련MSE: 179748895.9204, 훈련R2: 0.9699
# 검증MAE: 15298.3484, 검증MSE: 512731404.1579, 검증R2: 0.9125
# 테스트MAE: 18921.7802, 테스트MSE: 1054993834.4622, 테스트R2: 0.8879
# 과적합여부(R2 차이): 0.0574
#
# ===================================
# 모델 학습 소요 시간: 12.61초
# start_time:1742782606.5230262
#
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_MinMaxScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'max_iter': 200}
# 훈련MAE: 9342.6052, 훈련MSE: 195615785.1160, 훈련R2: 0.9672
# 검증MAE: 14549.4064, 검증MSE: 499185646.7630, 검증R2: 0.9148
# 테스트MAE: 18420.9664, 테스트MSE: 1189592685.1461, 테스트R2: 0.8736
# 과적합여부(R2 차이): 0.0524
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_MinMaxScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 5261.8569, 훈련MSE: 127043021.0375, 훈련R2: 0.9787
# 검증MAE: 14907.6732, 검증MSE: 517563276.5771, 검증R2: 0.9117
# 테스트MAE: 18062.8083, 테스트MSE: 1119222104.2253, 테스트R2: 0.8810
# 과적합여부(R2 차이): 0.0670
#
# ===================================
# 모델 학습 소요 시간: 3.00초
# start_time:1742782619.1320229
#
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_MinMaxScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200}
# 훈련MAE: 8192.8810, 훈련MSE: 127122312.3656, 훈련R2: 0.9787
# 검증MAE: 15409.4190, 검증MSE: 495007880.4793, 검증R2: 0.9155
# 테스트MAE: 18168.0430, 테스트MSE: 919637429.7294, 테스트R2: 0.9023
# 과적합여부(R2 차이): 0.0632
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_MinMaxScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 714.4966, 훈련MSE: 1039348.1462, 훈련R2: 0.9998
# 검증MAE: 15912.8316, 검증MSE: 591921872.9063, 검증R2: 0.8990
# 테스트MAE: 17634.9145, 테스트MSE: 694349871.7953, 테스트R2: 0.9262
# 과적합여부(R2 차이): 0.1008
#
# ===================================
# 모델 학습 소요 시간: 6.45초
# start_time:1742782622.1284306
#
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_RobustScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.6647, 훈련MSE: 931633756.3199, 훈련R2: 0.8438
# 검증MAE: 19883.7723, 검증MSE: 677925892.5602, 검증R2: 0.8843
# 테스트MAE: 22959.1351, 테스트MSE: 1622173379.8214, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_RobustScaler_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.6647, 훈련MSE: 931633756.3199, 훈련R2: 0.8438
# 검증MAE: 19883.7723, 검증MSE: 677925892.5602, 검증R2: 0.8843
# 테스트MAE: 22959.1351, 테스트MSE: 1622173379.8214, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 0.16초
# start_time:1742782629.0173664
#
# 🔹 최적 모델 저장 완료: saved_models/Ridge_RobustScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18673.0213, 훈련MSE: 969518880.7571, 훈련R2: 0.8375
# 검증MAE: 18913.0115, 검증MSE: 638760367.0139, 검증R2: 0.8910
# 테스트MAE: 22027.3811, 테스트MSE: 1659426110.5402, 테스트R2: 0.8236
# 과적합여부(R2 차이): -0.0535
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Ridge_RobustScaler_best.pkl
# 모델명: Ridge, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 18993.9905, 훈련MSE: 932505931.3290, 훈련R2: 0.8437
# 검증MAE: 19856.5549, 검증MSE: 674269570.7899, 검증R2: 0.8849
# 테스트MAE: 22903.3314, 테스트MSE: 1620780042.9166, 테스트R2: 0.8277
# 과적합여부(R2 차이): -0.0412
#
# ===================================
# 모델 학습 소요 시간: 0.11초
# start_time:1742782629.1749032
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.129e+11, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# 🔹 최적 모델 저장 완료: saved_models/Lasso_RobustScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18826.3488, 훈련MSE: 938723642.7363, 훈련R2: 0.8426
# 검증MAE: 19625.9120, 검증MSE: 652954326.5062, 검증R2: 0.8885
# 테스트MAE: 22622.6689, 테스트MSE: 1624496946.8616, 테스트R2: 0.8273
# 과적합여부(R2 차이): -0.0459
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Lasso_RobustScaler_best.pkl
# 모델명: Lasso, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 19000.5951, 훈련MSE: 931635756.8236, 훈련R2: 0.8438
# 검증MAE: 19881.9193, 검증MSE: 677600555.1314, 검증R2: 0.8843
# 테스트MAE: 22954.4534, 테스트MSE: 1622126601.2018, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 0.78초
# start_time:1742782629.2801187
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.129e+11, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Administrator\anaconda3\envs\pk_dl_202503\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.129e+11, tolerance: 6.967e+08
#   model = cd_fast.enet_coordinate_descent(
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_RobustScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 200}
# 훈련MAE: 7213.2534, 훈련MSE: 157972919.0196, 훈련R2: 0.9735
# 검증MAE: 15258.2518, 검증MSE: 523968249.1515, 검증R2: 0.9106
# 테스트MAE: 19692.2671, 테스트MSE: 1100204152.3156, 테스트R2: 0.8831
# 과적합여부(R2 차이): 0.0629
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_RobustScaler_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 6547.7155, 훈련MSE: 143848801.1993, 훈련R2: 0.9759
# 검증MAE: 14967.5276, 검증MSE: 536806758.8382, 검증R2: 0.9084
# 테스트MAE: 20261.3466, 테스트MSE: 1196261155.7942, 테스트R2: 0.8729
# 과적합여부(R2 차이): 0.0675
#
# ===================================
# 모델 학습 소요 시간: 15.24초
# start_time:1742782630.0618565
#
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_RobustScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 50}
# 훈련MAE: 884.2629, 훈련MSE: 2123743.7359, 훈련R2: 0.9996
# 검증MAE: 15575.7521, 검증MSE: 508828654.2369, 검증R2: 0.9131
# 테스트MAE: 19841.0290, 테스트MSE: 1274961961.2222, 테스트R2: 0.8645
# 과적합여부(R2 차이): 0.0865
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_RobustScaler_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 0.0000, 훈련MSE: 0.0000, 훈련R2: 1.0000
# 검증MAE: 14920.6765, 검증MSE: 477960263.3587, 검증R2: 0.9184
# 테스트MAE: 19743.2100, 테스트MSE: 1276113470.4929, 테스트R2: 0.8644
# 과적합여부(R2 차이): 0.0816
#
# ===================================
# 모델 학습 소요 시간: 5.91초
# start_time:1742782645.2970264
#
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_RobustScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# 훈련MAE: 7648.5368, 훈련MSE: 102921559.9290, 훈련R2: 0.9827
# 검증MAE: 14802.8037, 검증MSE: 496412768.0413, 검증R2: 0.9153
# 테스트MAE: 18234.2685, 테스트MSE: 1099903234.0113, 테스트R2: 0.8831
# 과적합여부(R2 차이): 0.0674
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_RobustScaler_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 9847.2682, 훈련MSE: 179748895.9204, 훈련R2: 0.9699
# 검증MAE: 15302.0962, 검증MSE: 513792351.9608, 검증R2: 0.9123
# 테스트MAE: 19204.5845, 테스트MSE: 1178190989.2154, 테스트R2: 0.8748
# 과적합여부(R2 차이): 0.0576
#
# ===================================
# 모델 학습 소요 시간: 11.97초
# start_time:1742782653.8675158
#
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_RobustScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'max_iter': 200}
# 훈련MAE: 9342.6052, 훈련MSE: 195615785.1160, 훈련R2: 0.9672
# 검증MAE: 14549.4064, 검증MSE: 499185646.7630, 검증R2: 0.9148
# 테스트MAE: 18420.9664, 테스트MSE: 1189592685.1461, 테스트R2: 0.8736
# 과적합여부(R2 차이): 0.0524
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_RobustScaler_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 5261.8569, 훈련MSE: 127043021.0375, 훈련R2: 0.9787
# 검증MAE: 14907.6732, 검증MSE: 517563276.5771, 검증R2: 0.9117
# 테스트MAE: 18062.8083, 테스트MSE: 1119222104.2253, 테스트R2: 0.8810
# 과적합여부(R2 차이): 0.0670
#
# ===================================
# 모델 학습 소요 시간: 2.94초
# start_time:1742782665.8360906
#
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_RobustScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200}
# 훈련MAE: 8192.8810, 훈련MSE: 127122312.3656, 훈련R2: 0.9787
# 검증MAE: 15409.4190, 검증MSE: 495007880.4793, 검증R2: 0.9155
# 테스트MAE: 18168.0430, 테스트MSE: 919637429.7294, 테스트R2: 0.9023
# 과적합여부(R2 차이): 0.0632
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_RobustScaler_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: RobustScaler 최적 하이퍼파라미터: {}
# 훈련MAE: 714.4966, 훈련MSE: 1039348.1462, 훈련R2: 0.9998
# 검증MAE: 15912.8316, 검증MSE: 591921872.9063, 검증R2: 0.8990
# 테스트MAE: 17634.9145, 테스트MSE: 694349871.7953, 테스트R2: 0.9262
# 과적합여부(R2 차이): 0.1008
#
# ===================================
# 모델 학습 소요 시간: 6.43초
# start_time:1742782668.7770543
#
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_No Scaling_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.6647, 훈련MSE: 931633756.3199, 훈련R2: 0.8438
# 검증MAE: 19883.7723, 검증MSE: 677925892.5599, 검증R2: 0.8843
# 테스트MAE: 22959.1351, 테스트MSE: 1622173379.8210, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/LinearRegression_No Scaling_best.pkl
# 모델명: LinearRegression, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 19003.6647, 훈련MSE: 931633756.3199, 훈련R2: 0.8438
# 검증MAE: 19883.7723, 검증MSE: 677925892.5599, 검증R2: 0.8843
# 테스트MAE: 22959.1351, 테스트MSE: 1622173379.8210, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 0.17초
# start_time:1742782675.6283789
#
# 🔹 최적 모델 저장 완료: saved_models/Ridge_No Scaling_best.pkl
# 모델명: Ridge, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18566.7057, 훈련MSE: 958769449.9376, 훈련R2: 0.8393
# 검증MAE: 19322.1844, 검증MSE: 658029485.7401, 검증R2: 0.8877
# 테스트MAE: 21958.4845, 테스트MSE: 1597567618.3725, 테스트R2: 0.8302
# 과적합여부(R2 차이): -0.0484
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Ridge_No Scaling_best.pkl
# 모델명: Ridge, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 18994.6934, 훈련MSE: 932502156.5588, 훈련R2: 0.8437
# 검증MAE: 19866.1291, 검증MSE: 674871315.3328, 검증R2: 0.8848
# 테스트MAE: 22902.5879, 테스트MSE: 1620099165.1757, 테스트R2: 0.8278
# 과적합여부(R2 차이): -0.0411
#
# ===================================
# 모델 학습 소요 시간: 0.12초
# start_time:1742782675.7973056
#
# 🔹 최적 모델 저장 완료: saved_models/Lasso_No Scaling_best.pkl
# 모델명: Lasso, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'alpha': 100, 'max_iter': 5000}
# 훈련MAE: 18803.5672, 훈련MSE: 938701615.3758, 훈련R2: 0.8426
# 검증MAE: 19718.7605, 검증MSE: 663382246.2186, 검증R2: 0.8868
# 테스트MAE: 22579.7955, 테스트MSE: 1614370625.2395, 테스트R2: 0.8284
# 과적합여부(R2 차이): -0.0442
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/Lasso_No Scaling_best.pkl
# 모델명: Lasso, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 19001.1175, 훈련MSE: 931635589.2050, 훈련R2: 0.8438
# 검증MAE: 19882.2722, 검증MSE: 677714545.6771, 검증R2: 0.8843
# 테스트MAE: 22954.2477, 테스트MSE: 1622008706.9513, 테스트R2: 0.8276
# 과적합여부(R2 차이): -0.0405
#
# ===================================
# 모델 학습 소요 시간: 0.17초
# start_time:1742782675.9170766
#
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_No Scaling_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 훈련MAE: 6503.0483, 훈련MSE: 138462576.2854, 훈련R2: 0.9768
# 검증MAE: 15639.8163, 검증MSE: 598103634.6295, 검증R2: 0.8979
# 테스트MAE: 19767.0219, 테스트MSE: 1107148469.1917, 테스트R2: 0.8823
# 과적합여부(R2 차이): 0.0789
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/RandomForestRegressor_No Scaling_best.pkl
# 모델명: RandomForestRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 6585.5906, 훈련MSE: 132708700.1546, 훈련R2: 0.9778
# 검증MAE: 15272.1836, 검증MSE: 557875427.3864, 검증R2: 0.9048
# 테스트MAE: 19412.8410, 테스트MSE: 1147965034.8554, 테스트R2: 0.8780
# 과적합여부(R2 차이): 0.0730
#
# ===================================
# 모델 학습 소요 시간: 14.16초
# start_time:1742782676.09019
#
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_No Scaling_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 훈련MAE: 5687.9865, 훈련MSE: 58190512.6406, 훈련R2: 0.9902
# 검증MAE: 15538.9795, 검증MSE: 487658555.6761, 검증R2: 0.9168
# 테스트MAE: 20474.3008, 테스트MSE: 1243219327.9173, 테스트R2: 0.8679
# 과적합여부(R2 차이): 0.0734
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/ExtraTreesRegressor_No Scaling_best.pkl
# 모델명: ExtraTreesRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 0.0000, 훈련MSE: 0.0000, 훈련R2: 1.0000
# 검증MAE: 14584.1704, 검증MSE: 464938905.3910, 검증R2: 0.9206
# 테스트MAE: 19556.9750, 테스트MSE: 1148860681.8148, 테스트R2: 0.8779
# 과적합여부(R2 차이): 0.0794
#
# ===================================
# 모델 학습 소요 시간: 5.60초
# start_time:1742782690.2466302
#
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_No Scaling_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 훈련MAE: 2907.4231, 훈련MSE: 14194211.0192, 훈련R2: 0.9976
# 검증MAE: 14372.0052, 검증MSE: 463521609.8279, 검증R2: 0.9209
# 테스트MAE: 17531.9964, 테스트MSE: 776669554.4851, 테스트R2: 0.9175
# 과적합여부(R2 차이): 0.0767
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/GradientBoostingRegressor_No Scaling_best.pkl
# 모델명: GradientBoostingRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 9847.2682, 훈련MSE: 179748895.9204, 훈련R2: 0.9699
# 검증MAE: 15255.4829, 검증MSE: 509145709.7655, 검증R2: 0.9131
# 테스트MAE: 18925.9776, 테스트MSE: 1086074984.2984, 테스트R2: 0.8846
# 과적합여부(R2 차이): 0.0568
#
# ===================================
# 모델 학습 소요 시간: 12.33초
# start_time:1742782698.4548469
#
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_No Scaling_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'max_iter': 200}
# 훈련MAE: 9342.6052, 훈련MSE: 195615785.1160, 훈련R2: 0.9672
# 검증MAE: 14549.4064, 검증MSE: 499185646.7630, 검증R2: 0.9148
# 테스트MAE: 18420.9664, 테스트MSE: 1189592685.1461, 테스트R2: 0.8736
# 과적합여부(R2 차이): 0.0524
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/HistGradientBoostingRegressor_No Scaling_best.pkl
# 모델명: HistGradientBoostingRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 5261.8569, 훈련MSE: 127043021.0375, 훈련R2: 0.9787
# 검증MAE: 14907.6732, 검증MSE: 517563276.5771, 검증R2: 0.9117
# 테스트MAE: 18062.8083, 테스트MSE: 1119222104.2253, 테스트R2: 0.8810
# 과적합여부(R2 차이): 0.0670
#
# ===================================
# 모델 학습 소요 시간: 2.91초
# start_time:1742782710.7877436
#
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_No Scaling_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200}
# 훈련MAE: 8192.8810, 훈련MSE: 127122312.3656, 훈련R2: 0.9787
# 검증MAE: 15409.4190, 검증MSE: 495007880.4793, 검증R2: 0.9155
# 테스트MAE: 18168.0430, 테스트MSE: 919637429.7294, 테스트R2: 0.9023
# 과적합여부(R2 차이): 0.0632
#
# ===================================
# 🔹 최적 모델 저장 완료: saved_models/XGBRegressor_No Scaling_best.pkl
# 모델명: XGBRegressor, 사용된 스케일러: No Scaling 최적 하이퍼파라미터: {}
# 훈련MAE: 714.4966, 훈련MSE: 1039348.1462, 훈련R2: 0.9998
# 검증MAE: 15912.8316, 검증MSE: 591921872.9063, 검증R2: 0.8990
# 테스트MAE: 17634.9145, 테스트MSE: 694349871.7953, 테스트R2: 0.9262
# 과적합여부(R2 차이): 0.1008
#
# ===================================
# 모델 학습 소요 시간: 7.03초
# start_time:1742782713.6934893

# %% [markdown]
# ### 최적의 모델 찾기

# %%
rs_df_train_r2= rs_df.sort_values("훈련R2", ascending=False)
rs_df_train_r2.head(10)
# Out:
#                               모델명  특성공학            스케일링  \
# 8             ExtraTreesRegressor     1  StandardScaler
# 36            ExtraTreesRegressor     1    RobustScaler
# 23      GradientBoostingRegressor     1    MinMaxScaler
# 51      GradientBoostingRegressor     1      No Scaling
# 22            ExtraTreesRegressor     1    MinMaxScaler
# 50            ExtraTreesRegressor     1      No Scaling
# 37      GradientBoostingRegressor     1    RobustScaler
# 9       GradientBoostingRegressor     1  StandardScaler
# 21          RandomForestRegressor     1    MinMaxScaler
# 12  HistGradientBoostingRegressor     1  StandardScaler
#
#                                            하이퍼파라메터_튜닝         훈련MSE  \
# 8   {'max_depth': 15, 'min_samples_split': 2, 'n_e...  1.544182e+06
# 36  {'max_depth': 15, 'min_samples_split': 2, 'n_e...  2.123744e+06
# 23  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  1.419421e+07
# 51  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  1.419421e+07
# 22  {'max_depth': 15, 'min_samples_split': 5, 'n_e...  1.733420e+07
# 50  {'max_depth': 10, 'min_samples_split': 2, 'n_e...  5.819051e+07
# 37  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  1.029216e+08
# 9   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  1.029216e+08
# 21                                                 {}  1.210948e+08
# 12                                                 {}  1.270430e+08
#
#            검증MSE        테스트MSE    훈련R2    검증R2   테스트R2   과적합여부
# 8   5.000494e+08  1.217405e+09  0.9997  0.9146  0.8706  0.0851
# 36  5.088287e+08  1.274962e+09  0.9996  0.9131  0.8645  0.0865
# 23  4.655700e+08  7.937480e+08  0.9976  0.9205  0.9156  0.0771
# 51  4.635216e+08  7.766696e+08  0.9976  0.9209  0.9175  0.0767
# 22  4.302546e+08  1.281538e+09  0.9971  0.9266  0.8638  0.0705
# 50  4.876586e+08  1.243219e+09  0.9902  0.9168  0.8679  0.0734
# 37  4.964128e+08  1.099903e+09  0.9827  0.9153  0.8831  0.0674
# 9   5.070529e+08  1.053585e+09  0.9827  0.9135  0.8880  0.0692
# 21  5.489735e+08  1.061871e+09  0.9797  0.9063  0.8871  0.0734
# 12  5.170035e+08  1.119222e+09  0.9787  0.9118  0.8810  0.0669

# %%
save_path = "./data/dt.xlsx"
rs_df_train_r2.to_excel(save_path, index=False)

# %%
"""
<해석>
기본 모델중 성능이 가장 좋은 모델 GradientBoostingRegressor : 훈련 R²: 0.9699, 검증 R²: 0.9091, 테스트 R²: 0.8822, 과적합 여부: 0.0607


===모델 성능 개선 후 가장 좋은 모델====
모델명: GradientBoostingRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
훈련R2: 0.9976, 검증R2: 0.9205, 테스트R2: 0.9156, 과적합여부(R2 차이): 0.0771 

튜닝 후 과적합이 근소하게 증가하였지만 훈련결정계수를 비롯하여 검증, 테스트 결정계수가 증가하여 해당 모델로 선정하였음.
따라서 검증 성능을 고려하면 튜닝된 GradientBoostingRegressor 더 뛰어난 성능의 모델로 판단됨

다만 결측치처리 이후의 상관관계가 궁금했고, 
상관관계가 낮은 것들이 특성중요도도 낮을까라는 의문이 생겨 각 상관관계, 특성중요도를 도출하여
비교하는 작업을 진행해 볼 예정입니다.

<진행과정>
상관관계(Spearmanr)가 높은 특성이 특성 중요도도 높은지 확인
상관관계가 낮은 특성이 특성 중요도도 낮은지 확인

데이터가 비선형 관계를 가질 때도 있기에 스피어만 상관계수로 확인
스피어만 상관분석 + P-value 필터링
P-value를 이용해 유의하지 않은 변수(의미 없는 변수) 제거
선택된 변수만 사용하여 모델을 다시 학습

특성 중요도 비교 분석
상관관계과 특성중요도에서의 영향을 미치는 컬럼들이 같은지 비교

상관관계는 낮지만 특성 중요도가 높은 변수 또는 그 반대의 경우 탐색
결론적으로, 상관관계가 높은 변수가 특성 중요도도 높은지, 그리고 상관관계가 낮은 변수가 특성 중요도도 낮은지 실제로 확인 예정
"""
# Out:
# "\n<해석>\n기본 모델중 성능이 가장 좋은 모델 XGBRegressor : 훈련 R²: 0.9998, 검증 R²: 0.9059, 테스트 R²: 0.9178, 과적합 여부: 0.0821\n\n===모델 성능 개선 후 가장 좋은 모델====\n모델명: ExtraTreesRegressor, 사용된 스케일러: MinMaxScaler 최적 하이퍼파라미터: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}\n훈련R2: 0.9997, 검증R2: 0.9216, 테스트R2: 0.8550, 과적합여부(R2 차이): 0.0781 \n\n튜닝 후 과적합이 0.0781로 줄어들었으며 모델의 일반화 성능이 더 좋아짐을 확인하였지만 다만 테스트 성능은 조금 감소하였다\n따라서 검증 성능을 고려하면 튜닝된 ExtraTreesRegressor가 더 안정적인 모델로 판단됨\n\n다만 결측치처리 이후의 상관관계가 궁금했고, \n상관관계가 낮은 것들이 특성중요도도 낮을까라는 의문이 생겨 각 상관관계, 특성중요도를 도출하여\n비교하는 작업을 진행해 볼 예정입니다.\n\n<진행과정>\n상관관계(Spearmanr)가 높은 특성이 특성 중요도도 높은지 확인\n상관관계가 낮은 특성이 특성 중요도도 낮은지 확인\n\n데이터가 비선형 관계를 가질 때도 있기에 스피어만 상관계수로 확인\n스피어만 상관분석 + P-value 필터링\nP-value를 이용해 유의하지 않은 변수(의미 없는 변수) 제거\n선택된 변수만 사용하여 모델을 다시 학습\n\n특성 중요도 비교 분석\n상관관계과 특성중요도에서의 영향을 미치는 컬럼들이 같은지 비교\n\n상관관계는 낮지만 특성 중요도가 높은 변수 또는 그 반대의 경우 탐색\n결론적으로, 상관관계가 높은 변수가 특성 중요도도 높은지, 그리고 상관관계가 낮은 변수가 특성 중요도도 낮은지 실제로 확인 예정\n"

# %% [markdown]
# ### EDA를 통한 상관관계 확인 및 시각화

# %%
# 상관관계 
cr = df.corr()
# cr
plt.figure(figsize=(40, 40))  # 그래프 크기 조정
plt.title("주택특성들 간 금액 예측(상관관계 매트릭스)")
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
# Out:
# <Axes: title={'center': '주택특성들 간 금액 예측(상관관계 매트릭스)'}>

# %% [markdown]
# ### 전처리 이후 상관계수 도출

# %%
# ### 종속변수, 독립변수 분리
# x = df.iloc[:,:-1]
# y = df["SalePrice"]
# print(x.shape, y.shape)
# 위에서 정의되어 있지만 확인차

correlation_matrix = df.corr()
# correlation_matrix
saleprice_corr = correlation_matrix["SalePrice"].abs()
saleprice_corr.sort_values(ascending=True)
# Out:
# BsmtFinType2    0.005323
# Condition2      0.007513
# BsmtFinSF2      0.011378
# Utilities       0.014314
# LandContour     0.015453
#                   ...
# GarageCars      0.640409
# ExterQual       0.682639
# GrLivArea       0.708624
# OverallQual     0.790982
# SalePrice       1.000000
# Name: SalePrice, Length: 80, dtype: float64

# %% [markdown]
# ### 전처리 이후 특성중요도 도출

# %%
### 종속변수, 독립변수 분리
x = df.iloc[:,:-1]
y = df["SalePrice"]
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1168, 79) (1168,)
# (146, 79) (146,)
# (146, 79) (146,)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

y_pred = rf_model.predict(x_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"Val MSE: {mse:.4f}")
print(f"Val R² Score: {r2:.4f}")

# 특성 중요도
feature_importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

# 특성 중요도 출력
print(feature_importance)
# Out:
# Val MSE: 522791700.3006
# Val R² Score: 0.9108
#          Feature  Importance
# 16   OverallQual    0.555236
# 45     GrLivArea    0.120953
# 43      2ndFlrSF    0.034469
# 37   TotalBsmtSF    0.033958
# 33    BsmtFinSF1    0.028072
# ..           ...         ...
# 44  LowQualFinSF    0.000056
# 73   MiscFeature    0.000036
# 74       MiscVal    0.000033
# 4         Street    0.000003
# 8      Utilities    0.000000
#
# [79 rows x 2 columns]

# %% [markdown]
# ### 스피어만 상관계수에서 상관계수 도출

# %%
plt.figure(figsize=(15, 10))
for col in df.columns.difference(["SalePrice"]):
    plt.scatter(df[col], df["SalePrice"], alpha=0.5, label=col, s=10)

plt.xlabel("독립변수")
plt.ylabel("SalePrice")
plt.title("독립변수 vs 가격")
plt.show()
# <해석>
# 비선형적인 그래프가 보이고 있으며,
# 피어슨 상관계수는 주로 선형 형태에서 사용되는 방법이기에 
# 선형 또는 비선형 관계를 모두 포함하여 검정 가능한 스피어만 상관계수를 사용하였음.

#  df라는 데이터프레임에서 "SalePrice"와 다른 모든 독립 변수들 간의 관계를 시각화
#  각 독립 변수와 "SalePrice"의 값을 산점도로 나타내는데, 각 점은 하나의 데이터 포인트를 나타내며, 
#  독립 변수 값은 x축에, "SalePrice" 값은 y축에 배치됩니다.

# %%
indep_column = x.columns
spearmanr(x[indep_column[0]],y)
# Out:
# SignificanceResult(statistic=0.007192252911733476, pvalue=0.7836360376210691)

# %%
for i in indep_column :
    s, p = spearmanr(x[i],y)
    i_msg = "유의미 하지 않음"

    if p < 0.05 :
        i_msg = "유의미 함"

    msg = f"""
        독립변수({i})와 종속변수(가격)의 상관관계 계수는 {s:.3f}이고,
        p-value의 값은 {p}임. 따라서 p-value < 0.05에 대하여 {i_msg}
    """
    print(msg)
# Out:
#         독립변수(MSSubClass)와 종속변수(가격)의 상관관계 계수는 0.007이고,
#         p-value의 값은 0.7836360376210691임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(MSZoning)와 종속변수(가격)의 상관관계 계수는 -0.335이고,
#         p-value의 값은 1.3404710391422381e-39임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LotFrontage)와 종속변수(가격)의 상관관계 계수는 0.385이고,
#         p-value의 값은 1.1882779562904924e-52임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LotArea)와 종속변수(가격)의 상관관계 계수는 0.456이고,
#         p-value의 값은 4.8715809571702074e-76임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Street)와 종속변수(가격)의 상관관계 계수는 0.046이고,
#         p-value의 값은 0.08012225427616039임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(Alley)와 종속변수(가격)의 상관관계 계수는 -0.122이고,
#         p-value의 값은 2.7936050827477304e-06임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LotShape)와 종속변수(가격)의 상관관계 계수는 -0.306이고,
#         p-value의 값은 5.267024377311837e-33임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LandContour)와 종속변수(가격)의 상관관계 계수는 -0.010이고,
#         p-value의 값은 0.696012147835915임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(Utilities)와 종속변수(가격)의 상관관계 계수는 -0.017이고,
#         p-value의 값은 0.5234925791824654임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(LotConfig)와 종속변수(가격)의 상관관계 계수는 -0.074이고,
#         p-value의 값은 0.004545067022881303임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LandSlope)와 종속변수(가격)의 상관관계 계수는 0.050이고,
#         p-value의 값은 0.05461545140646239임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(Neighborhood)와 종속변수(가격)의 상관관계 계수는 0.166이고,
#         p-value의 값은 1.934026300115169e-10임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Condition1)와 종속변수(가격)의 상관관계 계수는 0.187이고,
#         p-value의 값은 6.513476694742865e-13임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Condition2)와 종속변수(가격)의 상관관계 계수는 0.062이고,
#         p-value의 값은 0.01852558453668499임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BldgType)와 종속변수(가격)의 상관관계 계수는 -0.120이고,
#         p-value의 값은 4.320030347017548e-06임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(HouseStyle)와 종속변수(가격)의 상관관계 계수는 0.254이고,
#         p-value의 값은 7.142496007662556e-23임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(OverallQual)와 종속변수(가격)의 상관관계 계수는 0.810이고,
#         p-value의 값은 0.0임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(OverallCond)와 종속변수(가격)의 상관관계 계수는 -0.129이고,
#         p-value의 값은 7.118552262128731e-07임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(YearBuilt)와 종속변수(가격)의 상관관계 계수는 0.653이고,
#         p-value의 값은 5.693840951687133e-178임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(YearRemodAdd)와 종속변수(가격)의 상관관계 계수는 0.571이고,
#         p-value의 값은 3.557233443898463e-127임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(RoofStyle)와 종속변수(가격)의 상관관계 계수는 0.140이고,
#         p-value의 값은 7.546851408782939e-08임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(RoofMatl)와 종속변수(가격)의 상관관계 계수는 0.084이고,
#         p-value의 값은 0.0013420693669394554임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Exterior1st)와 종속변수(가격)의 상관관계 계수는 0.068이고,
#         p-value의 값은 0.00946755419636271임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Exterior2nd)와 종속변수(가격)의 상관관계 계수는 0.070이고,
#         p-value의 값은 0.007239690239792607임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(MasVnrType)와 종속변수(가격)의 상관관계 계수는 0.420이고,
#         p-value의 값은 2.2160649265396007e-63임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(MasVnrArea)와 종속변수(가격)의 상관관계 계수는 0.416이고,
#         p-value의 값은 3.7115496892406004e-62임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(ExterQual)와 종속변수(가격)의 상관관계 계수는 0.684이고,
#         p-value의 값은 5.605572202388652e-202임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(ExterCond)와 종속변수(가격)의 상관관계 계수는 0.012이고,
#         p-value의 값은 0.6555992149868093임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(Foundation)와 종속변수(가격)의 상관관계 계수는 0.492이고,
#         p-value의 값은 8.078796480614236e-90임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtQual)와 종속변수(가격)의 상관관계 계수는 0.678이고,
#         p-value의 값은 3.696558591966958e-197임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtCond)와 종속변수(가격)의 상관관계 계수는 0.269이고,
#         p-value의 값은 1.088293152608182e-25임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtExposure)와 종속변수(가격)의 상관관계 계수는 0.344이고,
#         p-value의 값은 7.175862714078988e-42임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtFinType1)와 종속변수(가격)의 상관관계 계수는 0.362이고,
#         p-value의 값은 2.443878483327234e-46임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtFinSF1)와 종속변수(가격)의 상관관계 계수는 0.302이고,
#         p-value의 값은 3.857909167679241e-32임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtFinType2)와 종속변수(가격)의 상관관계 계수는 0.040이고,
#         p-value의 값은 0.1283765288856581임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(BsmtFinSF2)와 종속변수(가격)의 상관관계 계수는 -0.039이고,
#         p-value의 값은 0.13832207880728556임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(BsmtUnfSF)와 종속변수(가격)의 상관관계 계수는 0.185이고,
#         p-value의 값은 9.88686055037851e-13임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(TotalBsmtSF)와 종속변수(가격)의 상관관계 계수는 0.603이고,
#         p-value의 값은 4.157299803636561e-145임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Heating)와 종속변수(가격)의 상관관계 계수는 -0.106이고,
#         p-value의 값은 4.799178150570142e-05임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(HeatingQC)와 종속변수(가격)의 상관관계 계수는 0.491이고,
#         p-value의 값은 1.3472242357065045e-89임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(CentralAir)와 종속변수(가격)의 상관관계 계수는 0.313이고,
#         p-value의 값은 1.3028329648335056e-34임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Electrical)와 종속변수(가격)의 상관관계 계수는 0.294이고,
#         p-value의 값은 1.3641220712014935e-30임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(1stFlrSF)와 종속변수(가격)의 상관관계 계수는 0.575이고,
#         p-value의 값은 1.7802462751091807e-129임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(2ndFlrSF)와 종속변수(가격)의 상관관계 계수는 0.294이고,
#         p-value의 값은 2.0403436410333482e-30임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(LowQualFinSF)와 종속변수(가격)의 상관관계 계수는 -0.068이고,
#         p-value의 값은 0.009645077992462557임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GrLivArea)와 종속변수(가격)의 상관관계 계수는 0.731이고,
#         p-value의 값은 1.4310154533091797e-244임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtFullBath)와 종속변수(가격)의 상관관계 계수는 0.225이고,
#         p-value의 값은 3.130150076241395e-18임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BsmtHalfBath)와 종속변수(가격)의 상관관계 계수는 -0.012이고,
#         p-value의 값은 0.6416774746324128임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(FullBath)와 종속변수(가격)의 상관관계 계수는 0.636이고,
#         p-value의 값은 2.7295740095874625e-166임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(HalfBath)와 종속변수(가격)의 상관관계 계수는 0.343이고,
#         p-value의 값은 1.4229500450097462e-41임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(BedroomAbvGr)와 종속변수(가격)의 상관관계 계수는 0.235이고,
#         p-value의 값은 9.402132344114265e-20임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(KitchenAbvGr)와 종속변수(가격)의 상관관계 계수는 -0.165이고,
#         p-value의 값은 2.3585159718449775e-10임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(KitchenQual)와 종속변수(가격)의 상관관계 계수는 -0.570이고,
#         p-value의 값은 1.77675753329943e-126임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(TotRmsAbvGrd)와 종속변수(가격)의 상관관계 계수는 0.533이고,
#         p-value의 값은 9.553211233237674e-108임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Functional)와 종속변수(가격)의 상관관계 계수는 0.135이고,
#         p-value의 값은 2.1258781186856963e-07임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Fireplaces)와 종속변수(가격)의 상관관계 계수는 0.519이고,
#         p-value의 값은 1.3546979782138591e-101임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(FireplaceQu)와 종속변수(가격)의 상관관계 계수는 0.538이고,
#         p-value의 값은 3.9330615765458644e-110임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageType)와 종속변수(가격)의 상관관계 계수는 -0.246이고,
#         p-value의 값은 1.2573682844795593e-21임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageYrBlt)와 종속변수(가격)의 상관관계 계수는 0.634이고,
#         p-value의 값은 4.919472516479396e-165임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageFinish)와 종속변수(가격)의 상관관계 계수는 -0.381이고,
#         p-value의 값은 8.709053875995303e-52임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageCars)와 종속변수(가격)의 상관관계 계수는 0.691이고,
#         p-value의 값은 1.6545168265608803e-207임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageArea)와 종속변수(가격)의 상관관계 계수는 0.649이고,
#         p-value의 값은 1.320918093357304e-175임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageQual)와 종속변수(가격)의 상관관계 계수는 0.351이고,
#         p-value의 값은 1.3364167636912787e-43임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(GarageCond)와 종속변수(가격)의 상관관계 계수는 0.339이고,
#         p-value의 값은 1.3608072354450557e-40임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(PavedDrive)와 종속변수(가격)의 상관관계 계수는 0.281이고,
#         p-value의 값은 8.018188351931824e-28임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(WoodDeckSF)와 종속변수(가격)의 상관관계 계수는 0.354이고,
#         p-value의 값은 2.6884841824960674e-44임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(OpenPorchSF)와 종속변수(가격)의 상관관계 계수는 0.478이고,
#         p-value의 값은 4.860098096441017e-84임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(EnclosedPorch)와 종속변수(가격)의 상관관계 계수는 -0.218이고,
#         p-value의 값은 3.180474171341712e-17임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(3SsnPorch)와 종속변수(가격)의 상관관계 계수는 0.065이고,
#         p-value의 값은 0.012384087320432493임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(ScreenPorch)와 종속변수(가격)의 상관관계 계수는 0.100이고,
#         p-value의 값은 0.0001281428771122835임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(PoolArea)와 종속변수(가격)의 상관관계 계수는 0.058이고,
#         p-value의 값은 0.025517129178227706임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(PoolQC)와 종속변수(가격)의 상관관계 계수는 0.058이고,
#         p-value의 값은 0.02547758428616182임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(Fence)와 종속변수(가격)의 상관관계 계수는 -0.186이고,
#         p-value의 값은 7.456052869575664e-13임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(MiscFeature)와 종속변수(가격)의 상관관계 계수는 -0.069이고,
#         p-value의 값은 0.007977222239461077임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(MiscVal)와 종속변수(가격)의 상관관계 계수는 -0.063이고,
#         p-value의 값은 0.016525262189967624임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(MoSold)와 종속변수(가격)의 상관관계 계수는 0.069이고,
#         p-value의 값은 0.007955956513825599임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(YrSold)와 종속변수(가격)의 상관관계 계수는 -0.030이고,
#         p-value의 값은 0.25356997604498915임. 따라서 p-value < 0.05에 대하여 유의미 하지 않음
#
#
#         독립변수(SaleType)와 종속변수(가격)의 상관관계 계수는 -0.176이고,
#         p-value의 값은 1.16812520200289e-11임. 따라서 p-value < 0.05에 대하여 유의미 함
#
#
#         독립변수(SaleCondition)와 종속변수(가격)의 상관관계 계수는 0.320이고,
#         p-value의 값은 4.843276489433243e-36임. 따라서 p-value < 0.05에 대하여 유의미 함

# %%
 ### spearmanr에서 유의미하지 않은 컬럼
 # MSSubClass, Street, LandContour, Utilities, LandSlope, ExterCond, BsmtFinType2, BsmtFinSF2, BsmtHalfBath, YrSold 10개 컬럼

df_fillter_spearmanr = df.drop(columns=["MSSubClass","Street","LandContour","LandSlope", "ExterCond", "BsmtFinType2", "BsmtFinSF2", "BsmtHalfBath", "YrSold"])
df_fillter_spearmanr
sns.scatterplot(df_fillter_spearmanr) # 비선형적인 그래프
# Out:
# <Axes: >

# %%
correlation_matrix = df_fillter_spearmanr.corr()
# correlation_matrix
saleprice_corr = correlation_matrix["SalePrice"].abs()
saleprice_corr.sort_values(ascending=True)
# Out:
# Condition2      0.007513
# Utilities       0.014314
# MiscVal         0.021190
# LowQualFinSF    0.025606
# 3SsnPorch       0.044584
#                   ...
# GarageCars      0.640409
# ExterQual       0.682639
# GrLivArea       0.708624
# OverallQual     0.790982
# SalePrice       1.000000
# Name: SalePrice, Length: 71, dtype: float64

# %% [markdown]
# ### 스피어만 상관계수에서 특성중요도 도출

# %%
x_spearmanr= df_fillter_spearmanr.drop(columns=["SalePrice"])
y_spearmanr = df_fillter_spearmanr["SalePrice"]

x_train, x_temp, y_train, y_temp = train_test_split(x_spearmanr, y_spearmanr, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# print(x_train.shape, y_train.shape)
# print(x_val.shape, y_val.shape)
# print(x_test.shape, y_test.shape)

# (1168, 70) (1168,)
# (146, 70) (146,)
# (146, 70) (146,)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

y_pred = rf_model.predict(x_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"Val MSE: {mse:.4f}")
print(f"Val R² Score: {r2:.4f}")

# 특성 중요도
feature_importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

# 특성 중요도 출력
print(feature_importance)
# Out:
# Val MSE: 511517868.3275
# Val R² Score: 0.9127
#          Feature    Importance
# 12   OverallQual  5.553137e-01
# 38     GrLivArea  1.214236e-01
# 30   TotalBsmtSF  3.476516e-02
# 36      2ndFlrSF  3.447004e-02
# 28    BsmtFinSF1  2.899005e-02
# ..           ...           ...
# 37  LowQualFinSF  6.053342e-05
# 17      RoofMatl  5.997243e-05
# 66       MiscVal  5.989982e-05
# 65   MiscFeature  4.109454e-05
# 5      Utilities  5.990403e-08
#
# [70 rows x 2 columns]

# %% [markdown]
# #### 전처리이후 스피어만 상관계수에서 차이

# %%
"""
<해석>                                              <해석>
                                                    모델 성능 평가
                                                    Val MSE: 549322240.9364
                                                    Val R² Score: 0.9062  모델의 예측력이 90.62을 의미하는 값으로 상당히 훈련이 잘된 것으로 판단됨
전처리 이전 데이터 중 상관관계가 높은 top 4            특성중요도 - 중요한 top 4
OverallQual     0.790982                            OverallQual     0.563296
GrLivArea       0.708624                            GrLivArea       0.124168
GarageCars      0.640409                            TotalBsmtSF     0.037689
GarageArea      0.623431                            2ndFlrSF        0.037295
                                                    

전처리 이전 데이터 중 상관관계가 낮은 top 4           특성중요도 - 중요하지 않은 top 4    
OverallCond     0.077856                            3SsnPorch       0.000533
MSSubClass      0.084284                            LowQualFinSF    0.000184
EnclosedPorch   0.128578                            MiscVal         0.000135
KitchenAbvGr    0.135907                            BsmtHalfBath    0.000116
================================================================================================================================================
<해석>                                              <해석>
                                                    모델 성능 평가
                                                    Val MSE: 522791700.3006
                                                    Val R² Score: 0.9108  모델의 예측력이 91.08을 의미하는 값으로 상당히 훈련이 잘된 것으로 판단됨
전처리 이후 데이터 중 상관관계가 높은 top 4            특성중요도 - 중요한 top 4
OverallQual     0.790982                            OverallQual     0.555236
GrLivArea       0.708624                            GrLivArea       0.120953
ExterQual       0.682639                            2ndFlrSF        0.034469
GarageCars      0.640409                            TotalBsmtSF     0.033958
                                                    

전처리 이후 데이터 중 상관관계가 낮은 top 4            특성중요도 - 중요하지 않은 top 4    
Condition2      0.007513                            Utilities       0.000000
BsmtFinSF2      0.011378                            Street          0.000003
Utilities       0.014314                            MiscVal         0.000033
LandContour     0.015453                            MiscFeature     0.000036
================================================================================================================================================
<해석>                                              <해석>
                                                    모델 성능 평가
                                                    Val MSE: 511517868.3275
                                                    Val R² Score: 0.9127  모델의 예측력이 91.27을 의미하는 값으로 상당히 훈련이 잘된 것으로 판단됨
스피어만 데이터 중 상관관계가 높은 top 4               특성중요도 - 중요한 top 4
OverallQual     0.790982                            OverallQual     0.55531
GrLivArea       0.708624                            GrLivArea       0.12142
ExterQual       0.682639                            TotalBsmtSF     0.03476
GarageCars      0.640409                            2ndFlrSF        0.03447


스피어만 데이터 중 상관관계가 낮은 top 4               특성중요도 - 중요하지 않은 top 4
Condition2      0.007513                            Utilities       0.0000000599
Utilities       0.014314                            MiscFeature     0.000041
MiscVal         0.021190                            MiscVal         0.0000599
LowQualFinSF    0.025606                            RoofMatl        0.0000599
"""


"""
<해석>
- 전처리를 통해 MSE가 549 → 522으로 줄어듦 → 즉, 평균적으로 예측 오차가 감소
    R² Score가 0.9062 → 0.9108로 증가 → 즉, 모델이 실제 집값을 더 잘 설명하였음, 스피어만 상관계수 사용 시 성능 최적화
    스피어만 데이터의 MSE가 가장 낮음 (511M) → 예측 오차가 가장 적음, R² Score가 0.9127로 가장 높음 → 즉, 설명력이 가장 뛰어남
 -- 전처리 후, ExterQual(외관 품질)이 새로운 중요한 변수로 포함됨
     전처리 이전에는 GarageArea(차고 면적)이 포함되었지만, 전처리 후 ExterQual(외관 품질)이 더 중요한 변수로 반영됨
     즉, 단순한 면적보다 외관 품질이 집값과 더 밀접한 관계가 있다는 것을 의미
     스피어만 데이터에서도 동일한 상관관계 유지
     스피어만 데이터를 적용했을 때도 ExterQual이 GarageArea보다 높은 중요도를 가짐
     이는 스피어만 상관계수가 비선형 관계까지 고려하여 좀 더 실제 가격과 관련된 변수를 잘 찾아냈을 가능성이 큼
 -- 전처리 후 불필요한 변수들이 정리됨
     BsmtFinSF2(지하실 마감 면적) 및 LandContour(토지 윤곽)가 제거됨, 
     대신, MiscVal(기타 값) 및 MiscFeature(기타 기능) 같은 중요도가 낮은 변수가 포함됨
     즉, 전처리를 통해 상대적으로 의미 없는 변수들이 정리되었다는 것을 의미, 스피어만 데이터에서도 불필요한 변수들이 유지되지만, 일부 조정됨
     LowQualFinSF(저품질 마감 면적) 및 RoofMatl(지붕 재료)가 추가됨, 이는 스피어만 방법이 변수 간 비선형 관계를 더 잘 반영한 결과일 가능성이 큼

 -- 가장 중요한 변수들은 거의 변함없음
     모든 경우에서 OverallQual(건축 품질)이 가장 중요한 변수, GrLivArea(거실 면적), TotalBsmtSF(지하실 면적), 2ndFlrSF(2층 면적)도 공통적으로 중요
     전처리 이후 변수 순위 변화
     전처리 이후 2ndFlrSF(2층 면적)의 중요도가 TotalBsmtSF보다 약간 높아짐, 이는 전처리를 통해 데이터가 정제되면서 변수 간 중요도가 조금씩 조정된 결과
     스피어만 데이터를 적용했을 때 큰 차이는 없지만, 중요도 값이 더 세밀하게 반영됨
     TotalBsmtSF와 2ndFlrSF의 중요도가 근소한 차이로 변화
     스피어만 데이터가 변수의 중요도를 조금 더 정밀하게 반영하는 효과를 보임


<의존성과 인과성 관련 인사이트 도출>
상관관계(피어슨 & 스피어만) 기반 변수 간 의존성 분석

(1) 전처리 이전 vs 이후 vs 스피어만 데이터에서 상관관계가 높은 변수
모든 데이터에서 OverallQual, GrLivArea 등은 집값(SalePrice)과 높은 상관관계를 가짐
전처리 후에는 ExterQual(외관 품질)이 추가됨 → 즉, 전처리를 통해 집값과 더 밀접한 변수가 반영됨
스피어만 데이터에서도 ExterQual이 유지됨 → 즉, 비선형 관계까지 고려해도 이 변수는 여전히 중요한 변수임

(2) 상관관계가 낮은 변수
Condition2, Utilities, MiscVal 등은 상관관계가 낮거나 거의 없음
전처리 후에도 여전히 중요도가 낮은 변수들은 유지됨
즉, 집값과 상관이 없는 변수들은 지속적으로 낮은 중요도를 가짐 → 제거해도 모델 성능에는 큰 영향을 주지 않음
"""
# Out:
# '\n<해석>\n- 전처리를 통해 MSE가 549 → 522으로 줄어듦 → 즉, 평균적으로 예측 오차가 감소\n    R² Score가 0.9062 → 0.9108로 증가 → 즉, 모델이 실제 집값을 더 잘 설명하였음, 스피어만 상관계수 사용 시 성능 최적화\n    스피어만 데이터의 MSE가 가장 낮음 (511M) → 예측 오차가 가장 적음, R² Score가 0.9127로 가장 높음 → 즉, 설명력이 가장 뛰어남\n -- 전처리 후, ExterQual(외관 품질)이 새로운 중요한 변수로 포함됨\n     전처리 이전에는 GarageArea(차고 면적)이 포함되었지만, 전처리 후 ExterQual(외관 품질)이 더 중요한 변수로 반영됨\n     즉, 단순한 면적보다 외관 품질이 집값과 더 밀접한 관계가 있다는 것을 의미\n     스피어만 데이터에서도 동일한 상관관계 유지\n     스피어만 데이터를 적용했을 때도 ExterQual이 GarageArea보다 높은 중요도를 가짐\n     이는 스피어만 상관계수가 비선형 관계까지 고려하여 좀 더 실제 가격과 관련된 변수를 잘 찾아냈을 가능성이 큼\n -- 전처리 후 불필요한 변수들이 정리됨\n     BsmtFinSF2(지하실 마감 면적) 및 LandContour(토지 윤곽)가 제거됨, \n     대신, MiscVal(기타 값) 및 MiscFeature(기타 기능) 같은 중요도가 낮은 변수가 포함됨\n     즉, 전처리를 통해 상대적으로 의미 없는 변수들이 정리되었다는 것을 의미, 스피어만 데이터에서도 불필요한 변수들이 유지되지만, 일부 조정됨\n     LowQualFinSF(저품질 마감 면적) 및 RoofMatl(지붕 재료)가 추가됨, 이는 스피어만 방법이 변수 간 비선형 관계를 더 잘 반영한 결과일 가능성이 큼\n\n -- 가장 중요한 변수들은 거의 변함없음\n     모든 경우에서 OverallQual(건축 품질)이 가장 중요한 변수, GrLivArea(거실 면적), TotalBsmtSF(지하실 면적), 2ndFlrSF(2층 면적)도 공통적으로 중요\n     전처리 이후 변수 순위 변화\n     전처리 이후 2ndFlrSF(2층 면적)의 중요도가 TotalBsmtSF보다 약간 높아짐, 이는 전처리를 통해 데이터가 정제되면서 변수 간 중요도가 조금씩 조정된 결과\n     스피어만 데이터를 적용했을 때 큰 차이는 없지만, 중요도 값이 더 세밀하게 반영됨\n     TotalBsmtSF와 2ndFlrSF의 중요도가 근소한 차이로 변화\n     스피어만 데이터가 변수의 중요도를 조금 더 정밀하게 반영하는 효과를 보임\n\n\n<의존성과 인과성 관련 인사이트 도출>\n상관관계(피어슨 & 스피어만) 기반 변수 간 의존성 분석\n\n(1) 전처리 이전 vs 이후 vs 스피어만 데이터에서 상관관계가 높은 변수\n모든 데이터에서 OverallQual, GrLivArea 등은 집값(SalePrice)과 높은 상관관계를 가짐\n전처리 후에는 ExterQual(외관 품질)이 추가됨 → 즉, 전처리를 통해 집값과 더 밀접한 변수가 반영됨\n스피어만 데이터에서도 ExterQual이 유지됨 → 즉, 비선형 관계까지 고려해도 이 변수는 여전히 중요한 변수임\n\n(2) 상관관계가 낮은 변수\nCondition2, Utilities, MiscVal 등은 상관관계가 낮거나 거의 없음\n전처리 후에도 여전히 중요도가 낮은 변수들은 유지됨\n즉, 집값과 상관이 없는 변수들은 지속적으로 낮은 중요도를 가짐 → 제거해도 모델 성능에는 큰 영향을 주지 않음\n'

# %%
"""
(왜 하는지 궁금하면,,,)
처음엔 전체 데이터에서 상관계수와 중요도를 확인하고, 의미 없는 특성을 제거한 후 다시 분석하는 이유는,

필요 없는 특성을 제외하여 모델 성능을 높이고, 해석력을 개선하기 위해서
원본 분석은 전체적인 특성 중요도와 관계 파악,
스피어만 상관분석은 불필요한 특성을 제거한 후 다시 특성 간 관계를 정리하여 최적의 변수 선택하는 과정
"""
# Out:
# '\n(왜 하는지 궁금하면,,,)\n처음엔 전체 데이터에서 상관계수와 중요도를 확인하고, 의미 없는 특성을 제거한 후 다시 분석하는 이유는,\n\n필요 없는 특성을 제외하여 모델 성능을 높이고, 해석력을 개선하기 위해서\n원본 분석은 전체적인 특성 중요도와 관계 파악,\n스피어만 상관분석은 불필요한 특성을 제거한 후 다시 특성 간 관계를 정리하여 최적의 변수 선택하는 과정\n'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       1 scalers = {"StandardScaler": StandardScaler(),
#       2         "MinMaxScaler": MinMaxScaler(),
#       3         "RobustScaler": RobustScaler(),
#       4         "No Scaling": None}
#       6 for scaler_name, scaler in scalers.items():
# ----> 7     print(SCA)
#       8     if scaler:
#       9         train_scaled = scaler.fit_transform(train_poly)
#
# NameError: name 'SCA' is not defined
